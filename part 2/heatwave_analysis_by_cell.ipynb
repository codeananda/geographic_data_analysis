# %% [markdown]
# # Heatwave Analysis by Cell
#
# Graphing:
# * Change in number
# * Change in magnitude
#
# For tasmax and tasmin
#
# 4 graphs per cell.
#
# Graphing or raw data is going to be 300 pages long.
#
# For each cell, load up tasmax, tasmin and a graph of 4 subgrapsh (change in num and change in max for both of them)
#
# 1. NUmber of heatwave days per year - absolute number and percentage (on same graph as they are linked)
# 2. Highest value per year for each graph
#
# 1. Length
# 2. Percentage of days
# 3. Highest value

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Automatically parse dates when reading in all csv files
# Less lines of code and gives us access to the full power of datetime indexes
tasmax_heat = pd.read_csv('tasmax_heatwaves.csv', parse_dates=['date'])
tasmax_heat = tasmax_heat.set_index(['lon', 'lat', 'date'])

tasmin_heat = pd.read_csv('tasmin_heatwaves.csv', parse_dates=['date'])
tasmin_heat = tasmin_heat.set_index(['lon', 'lat', 'date'])

tasmax = pd.read_csv('tasmax.csv', parse_dates=['date'])
tasmax = tasmax.set_index(['lon', 'lat', 'date'])

tasmin = pd.read_csv('tasmin.csv', parse_dates=['date'])
tasmin = tasmin.set_index(['lon', 'lat', 'date'])

# Need this to get all the cells
tasmax_other = pd.read_csv('tasmax_heatwaves.csv', parse_dates=['date'])
tasmax_other = tasmax_other.set_index(['lon', 'lat'])

# %%
# Store cells in variable
cells = list(np.unique(tasmax_other.index))

# %%
# Creates analysis.csv - is quite slow
def create_analysis_csv():
    for i, cell in enumerate(cells):
        df_cell = pd.DataFrame()
        for year in range(2006, 2099):
            # Note: both the start and end date are included in the slice (this was the bug from before)
            # If we do .loc['2006': '2007'] it selects data from 2006 and 2007
            # So, we select a range from the start of this year to the end of it 
            # i.e. .loc['2006': '2006'] selects all data from 2006
            # This returns an empty dataframe if there is no data for that year
            # if we do not slice (.loc['2006']), we may get a KeyError if there are, for example, no heatwaves 
            # recorded in 2006
            data_tasmin_heat = tasmin_heat.loc[cell].loc[f'{year}': f'{year}'] 
            data_tasmax_heat = tasmax_heat.loc[cell].loc[f'{year}': f'{year}']
            
            data_tasmin = tasmin.loc[cell].loc[f'{year}': f'{year}']  
            data_tasmax = tasmax.loc[cell].loc[f'{year}': f'{year}'] 
            
            lon, lat = cell[0], cell[1]

            tasmin_num_days, tasmax_num_days = len(data_tasmin_heat), len(data_tasmax_heat)
            tasmin_pct_days, tasmax_pct_days = len(data_tasmin_heat)/365.25, len(data_tasmax_heat)/365.25
            
            tasmin_max_temp = float(data_tasmin.max())
            tasmax_max_temp = float(data_tasmax.max())

            data_dict = {'lon': lon,
                        'lat': lat,
                        'year': np.datetime64(str(year)),
                        'tasmax_num_days': tasmax_num_days,
                        'tasmax_pct_days': tasmax_pct_days,
                        'tasmax_max_temp': tasmax_max_temp,
                        'tasmin_num_days': tasmin_num_days,
                        'tasmin_pct_days': tasmin_pct_days,
                        'tasmin_max_temp': tasmin_max_temp}

            df = pd.DataFrame(data_dict, index=[0])
            df = df.set_index(['lon', 'lat'])
            
            if i == 0 and year == 2006:
                df.to_csv('analysis.csv')
            else:
                df.to_csv('analysis.csv', mode='a', header=False)
        print(f'Index {i}/{len(cells)-1} - it worked for {cell}')

# %%
create_analysis_csv()
# Out:
# /Users/king/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16
# Index 359/363 - it worked for (140.75, 38.25)
# Index 360/363 - it worked for (140.75, 40.75)
# Index 361/363 - it worked for (141.25, 43.25)
# Index 362/363 - it worked for (142.75, -3.25)
# Index 363/363 - it worked for (144.75, -6.25)

# %%
analysis = pd.read_csv('analysis.csv')
analysis = analysis.set_index(['lon', 'lat', 'year'])
analysis
# Out:
#                            tasmax_num_days  tasmax_pct_days  tasmax_max_temp  \
# lon     lat    year
# -122.75  42.25 2006-01-01               27         0.073922       310.828217
#                2007-01-01               17         0.046543       310.177887
#                2008-01-01               20         0.054757       307.915619
#                2009-01-01               30         0.082136       316.693970
#                2010-01-01               35         0.095825       312.144409
# ...                                    ...              ...              ...
#  144.75 -6.25  2094-01-01               15         0.041068       316.924896
#                2095-01-01               16         0.043806       316.329315
#                2096-01-01               16         0.043806       318.168640
#                2097-01-01               41         0.112252       315.393127
#                2098-01-01               38         0.104038       322.137512
#
#                            tasmin_num_days  tasmin_pct_days  tasmin_max_temp
# lon     lat    year
# -122.75  42.25 2006-01-01               24         0.065708       294.072998
#                2007-01-01               16         0.043806       289.881714
#                2008-01-01               17         0.046543       288.854095
#                2009-01-01               25         0.068446       295.634766
#                2010-01-01               39         0.106776       292.761444
# ...                                    ...              ...              ...
#  144.75 -6.25  2094-01-01              607         1.661875       296.912415
#                2095-01-01              558         1.527721       296.972382
#                2096-01-01              553         1.514031       296.531097
#                2097-01-01              555         1.519507       295.959137
#                2098-01-01              600         1.642710       297.205872
#
# [33852 rows x 6 columns]

# %%
analysis.loc[-122.75, 42.25].tasmax_num_days.plot()

# %%
# Creates all the plots in your current working directory
def create_actual_data_plots():
    for i, cell in enumerate(cells):
        fig, axes = plt.subplots(2, 2, figsize=(8, 11), sharex=True)

        data = analysis.loc[cell]
        rolling = data.rolling(window=5, win_type='exponential')
        rolling_mean = rolling.mean(tau=20)

        axes[0, 0].plot(data.tasmax_num_days, 'r', label='Actual')
        axes[0, 0].plot(rolling_mean.tasmax_num_days, 'k', label='Rolling mean')
        axes[0, 0].set(title='Tasmax Num Days')
        axes[0, 0].legend()


        axes[0, 1].plot(data.tasmin_num_days, 'b', label='Actual')
        axes[0, 1].plot(rolling_mean.tasmin_num_days, 'k', label='Rolling mean')
        axes[0, 1].set(title='Tasmin Num Days')
        axes[0, 1].legend()

        axes[1, 0].plot(data.tasmax_max_temp, 'r')
        axes[1, 0].plot(rolling_mean.tasmax_max_temp, 'k')
        axes[1, 0].set(title='Tasmax Max Temperature', xlabel='Date (2006-2099)')

        axes[1, 1].plot(data.tasmin_max_temp, 'b')
        axes[1, 1].plot(rolling_mean.tasmin_max_temp, 'k')
        axes[1, 1].set(title='Tasmin Max Temperature', xlabel='Date (2006-2099)')

        axes[1, 0].set_xticks([])
        axes[1, 1].set_xticks([])

        plt.tight_layout()

        fig.suptitle(f'{cell}')
        plt.savefig(f'plots\{cell}.pdf')
        plt.close()
        print(f'Index {i} worked for {cell}')

# %%
create_actual_data_plots()
# Out:
# Index 0 worked for (-122.75, 42.25)
# Index 1 worked for (-119.75, 34.25)
# Index 2 worked for (-118.25, 34.75)
# Index 3 worked for (-109.75, 31.25)
# Index 4 worked for (-106.75, 32.25)
# Index 5 worked for (-106.25, 28.75)
# Index 6 worked for (-103.25, 25.75)
# Index 7 worked for (-102.75, 20.75)
# Index 8 worked for (-99.75, 16.75)
# Index 9 worked for (-99.75, 17.75)
# Index 10 worked for (-98.75, 20.25)
# Index 11 worked for (-98.25, 34.75)
# Index 12 worked for (-97.75, 25.75)
# Index 13 worked for (-97.25, 19.75)
# Index 14 worked for (-96.25, 42.25)
# Index 15 worked for (-91.25, 14.25)
# Index 16 worked for (-90.75, 42.75)
# Index 17 worked for (-88.25, 15.25)
# Index 18 worked for (-87.75, 42.25)
# Index 19 worked for (-85.75, 42.75)
# Index 20 worked for (-84.75, 42.75)
# Index 21 worked for (-84.25, 33.75)
# Index 22 worked for (-79.75, -1.25)
# Index 23 worked for (-79.25, 44.25)
# Index 24 worked for (-77.75, 21.25)
# Index 25 worked for (-76.25, 4.25)
# Index 26 worked for (-75.25, 7.75)
# Index 27 worked for (-73.75, 18.25)
# Index 28 worked for (-73.25, -40.75)
# Index 29 worked for (-73.25, 41.25)
# Index 30 worked for (-72.75, 10.25)
# Index 31 worked for (-72.75, 46.25)
# Index 32 worked for (-71.75, -35.75)
# Index 33 worked for (-71.25, 10.25)
# Index 34 worked for (-69.25, 9.75)
# Index 35 worked for (-65.75, -27.25)
# Index 36 worked for (-64.75, -21.75)
# Index 37 worked for (-62.25, 8.25)
# Index 38 worked for (-60.75, -32.75)
# Index 39 worked for (-58.75, -38.75)
# Index 40 worked for (-56.25, -25.75)
# Index 41 worked for (-54.25, -31.25)
# Index 42 worked for (-53.25, -26.25)
# Index 43 worked for (-51.25, -22.25)
# Index 44 worked for (-50.25, -29.75)
# Index 45 worked for (-50.25, -27.75)
# Index 46 worked for (-48.75, -2.75)
# Index 47 worked for (-47.75, -23.25)
# Index 48 worked for (-47.75, -18.25)
# Index 49 worked for (-47.25, -2.75)
# Index 50 worked for (-46.75, -23.75)
# Index 51 worked for (-44.25, -22.75)
# Index 52 worked for (-44.25, -19.25)
# Index 53 worked for (-43.25, -4.75)
# Index 54 worked for (-42.75, -14.25)
# Index 55 worked for (-39.25, -13.25)
# Index 56 worked for (-39.25, -6.25)
# Index 57 worked for (-37.25, -8.25)
# Index 58 worked for (-13.75, 10.25)
# Index 59 worked for (-13.75, 11.25)
# Index 60 worked for (-11.75, 7.75)
# Index 61 worked for (-10.75, 11.25)
# Index 62 worked for (-10.25, 9.25)
# Index 63 worked for (-9.25, 30.25)
# Index 64 worked for (-9.25, 53.25)
# Index 65 worked for (-7.75, 31.75)
# Index 66 worked for (-6.75, 38.75)
# Index 67 worked for (-5.75, 9.25)
# Index 68 worked for (-5.75, 35.75)
# Index 69 worked for (-5.75, 43.75)
# Index 70 worked for (-5.25, 6.75)
# Index 71 worked for (-5.25, 12.25)
# Index 72 worked for (-4.25, 36.75)
# Index 73 worked for (-4.25, 43.25)
# Index 74 worked for (-3.75, 55.75)
# Index 75 worked for (-2.75, 52.75)
# Index 76 worked for (-2.25, 13.25)
# Index 77 worked for (-2.25, 52.75)
# Index 78 worked for (-1.75, 7.75)
# Index 79 worked for (-1.75, 43.25)
# Index 80 worked for (-1.25, 7.25)
# Index 81 worked for (-1.25, 51.75)
# Index 82 worked for (-1.25, 53.75)
# Index 83 worked for (1.25, 7.75)
# Index 84 worked for (1.25, 9.75)
# Index 85 worked for (1.75, 12.75)
# Index 86 worked for (1.75, 52.25)
# Index 87 worked for (4.25, 32.75)
# Index 88 worked for (4.25, 35.25)
# Index 89 worked for (4.25, 51.75)
# Index 90 worked for (4.75, 8.75)
# Index 91 worked for (5.25, 34.25)
# Index 92 worked for (5.75, 6.25)
# Index 93 worked for (5.75, 8.75)
# Index 94 worked for (6.25, 35.75)
# Index 95 worked for (6.75, 8.25)
# Index 96 worked for (6.75, 9.75)
# Index 97 worked for (6.75, 11.75)
# Index 98 worked for (6.75, 12.25)
# Index 99 worked for (6.75, 13.75)
# Index 100 worked for (7.25, 9.25)
# Index 101 worked for (7.25, 35.75)
# Index 102 worked for (7.25, 48.25)
# Index 103 worked for (7.75, 5.25)
# Index 104 worked for (7.75, 48.75)
# Index 105 worked for (8.75, 13.75)
# Index 106 worked for (8.75, 35.25)
# Index 107 worked for (9.25, 48.25)
# Index 108 worked for (10.25, 7.25)
# Index 109 worked for (10.25, 35.75)
# Index 110 worked for (10.25, 43.75)
# Index 111 worked for (10.25, 44.75)
# Index 112 worked for (10.25, 47.75)
# Index 113 worked for (10.75, 45.25)
# Index 114 worked for (11.75, 2.75)
# Index 115 worked for (11.75, 11.75)
# Index 116 worked for (12.25, 9.75)
# Index 117 worked for (12.25, 11.25)
# Index 118 worked for (12.75, 2.75)
# Index 119 worked for (13.25, -1.75)
# Index 120 worked for (13.75, 11.75)
# Index 121 worked for (14.25, -5.75)
# Index 122 worked for (14.25, 9.75)
# Index 123 worked for (14.25, 14.25)
# Index 124 worked for (14.75, -5.75)
# Index 125 worked for (15.25, 37.75)
# Index 126 worked for (16.25, 1.75)
# Index 127 worked for (16.75, 40.75)
# Index 128 worked for (17.25, -12.25)
# Index 129 worked for (17.75, 8.75)
# Index 130 worked for (18.25, 52.75)
# Index 131 worked for (18.75, 8.75)
# Index 132 worked for (20.25, -9.75)
# Index 133 worked for (21.75, 43.25)
# Index 134 worked for (22.25, -5.25)
# Index 135 worked for (22.25, 4.25)
# Index 136 worked for (24.25, 11.75)
# Index 137 worked for (25.75, 48.25)
# Index 138 worked for (26.75, 47.75)
# Index 139 worked for (27.25, -9.25)
# Index 140 worked for (27.25, 42.25)
# Index 141 worked for (27.75, 40.75)
# Index 142 worked for (27.75, 53.75)
# Index 143 worked for (28.75, -12.75)
# Index 144 worked for (28.75, -2.75)
# Index 145 worked for (28.75, -1.75)
# Index 146 worked for (29.25, -5.75)
# Index 147 worked for (29.25, 14.25)
# Index 148 worked for (29.75, 0.75)
# Index 149 worked for (29.75, 59.75)
# Index 150 worked for (30.25, -4.75)
# Index 151 worked for (30.25, 13.25)
# Index 152 worked for (30.75, 52.25)
# Index 153 worked for (31.25, 29.25)
# Index 154 worked for (31.25, 36.75)
# Index 155 worked for (31.75, -16.25)
# Index 156 worked for (31.75, 40.75)
# Index 157 worked for (32.25, 13.75)
# Index 158 worked for (33.25, -18.25)
# Index 159 worked for (33.25, -3.75)
# Index 160 worked for (33.25, 51.75)
# Index 161 worked for (33.75, -25.25)
# Index 162 worked for (33.75, -16.25)
# Index 163 worked for (33.75, -9.75)
# Index 164 worked for (34.25, 0.75)
# Index 165 worked for (35.25, -16.25)
# Index 166 worked for (35.25, 33.25)
# Index 167 worked for (35.25, 47.75)
# Index 168 worked for (35.75, -4.25)
# Index 169 worked for (35.75, 35.75)
# Index 170 worked for (36.75, 11.25)
# Index 171 worked for (36.75, 15.25)
# Index 172 worked for (36.75, 18.75)
# Index 173 worked for (36.75, 45.25)
# Index 174 worked for (37.75, 47.75)
# Index 175 worked for (38.25, 11.25)
# Index 176 worked for (38.25, 13.25)
# Index 177 worked for (38.75, 11.75)
# Index 178 worked for (38.75, 14.25)
# Index 179 worked for (38.75, 14.75)
# Index 180 worked for (38.75, 47.25)
# Index 181 worked for (39.75, -13.25)
# Index 182 worked for (39.75, 10.75)
# Index 183 worked for (39.75, 24.25)
# Index 184 worked for (39.75, 43.75)
# Index 185 worked for (39.75, 57.75)
# Index 186 worked for (40.25, 0.25)
# Index 187 worked for (40.75, 37.25)
# Index 188 worked for (42.25, 57.25)
# Index 189 worked for (42.75, -0.25)
# Index 190 worked for (43.25, -11.75)
# Index 191 worked for (43.25, 35.75)
# Index 192 worked for (43.25, 39.25)
# Index 193 worked for (43.75, 26.25)
# Index 194 worked for (43.75, 43.75)
# Index 195 worked for (44.25, 46.25)
# Index 196 worked for (44.75, 32.75)
# Index 197 worked for (45.75, 37.25)
# Index 198 worked for (46.75, 30.75)
# Index 199 worked for (47.25, -19.75)
# Index 200 worked for (47.25, 17.25)
# Index 201 worked for (47.75, 29.25)
# Index 202 worked for (47.75, 30.25)
# Index 203 worked for (48.25, 29.25)
# Index 204 worked for (48.75, 37.75)
# Index 205 worked for (48.75, 38.25)
# Index 206 worked for (48.75, 39.25)
# Index 207 worked for (49.25, 55.75)
# Index 208 worked for (50.25, 35.25)
# Index 209 worked for (51.25, 33.75)
# Index 210 worked for (51.25, 51.25)
# Index 211 worked for (53.75, 28.75)
# Index 212 worked for (59.25, 36.25)
# Index 213 worked for (59.75, 55.25)
# Index 214 worked for (63.25, 61.25)
# Index 215 worked for (66.25, 39.75)
# Index 216 worked for (66.75, 29.25)
# Index 217 worked for (68.25, 33.75)
# Index 218 worked for (68.75, 35.75)
# Index 219 worked for (69.75, 32.25)
# Index 220 worked for (69.75, 33.25)
# Index 221 worked for (69.75, 36.75)
# Index 222 worked for (70.25, 28.25)
# Index 223 worked for (70.25, 34.75)
# Index 224 worked for (70.75, 29.75)
# Index 225 worked for (70.75, 40.25)
# Index 226 worked for (72.75, 23.75)
# Index 227 worked for (72.75, 32.75)
# Index 228 worked for (73.25, 34.25)
# Index 229 worked for (73.75, 4.25)
# Index 230 worked for (74.25, 14.25)
# Index 231 worked for (74.25, 17.25)
# Index 232 worked for (74.25, 20.75)
# Index 233 worked for (74.75, 18.75)
# Index 234 worked for (74.75, 26.75)
# Index 235 worked for (75.25, 13.75)
# Index 236 worked for (75.25, 19.25)
# Index 237 worked for (75.25, 21.75)
# Index 238 worked for (75.75, 17.75)
# Index 239 worked for (76.25, 12.75)
# Index 240 worked for (76.75, 25.75)
# Index 241 worked for (76.75, 30.75)
# Index 242 worked for (76.75, 43.25)
# Index 243 worked for (76.75, 66.25)
# Index 244 worked for (77.75, 19.75)
# Index 245 worked for (78.25, 10.75)
# Index 246 worked for (78.25, 12.75)
# Index 247 worked for (78.25, 15.25)
# Index 248 worked for (78.25, 24.25)
# Index 249 worked for (78.75, 11.75)
# Index 250 worked for (79.25, 9.75)
# Index 251 worked for (79.25, 19.25)
# Index 252 worked for (79.75, 28.75)
# Index 253 worked for (80.25, 15.75)
# Index 254 worked for (80.25, 21.75)
# Index 255 worked for (80.75, 16.75)
# Index 256 worked for (81.75, 7.75)
# Index 257 worked for (81.75, 27.25)
# Index 258 worked for (82.25, 17.75)
# Index 259 worked for (82.25, 26.75)
# Index 260 worked for (83.25, 21.75)
# Index 261 worked for (83.25, 27.75)
# Index 262 worked for (83.75, 28.25)
# Index 263 worked for (84.25, 23.25)
# Index 264 worked for (84.25, 24.75)
# Index 265 worked for (84.75, 23.25)
# Index 266 worked for (85.75, 22.25)
# Index 267 worked for (86.25, 21.25)
# Index 268 worked for (87.25, 24.25)
# Index 269 worked for (87.75, 44.25)
# Index 270 worked for (88.25, 22.75)
# Index 271 worked for (88.25, 25.75)
# Index 272 worked for (88.75, 22.75)
# Index 273 worked for (88.75, 23.75)
# Index 274 worked for (88.75, 25.75)
# Index 275 worked for (89.75, 22.75)
# Index 276 worked for (89.75, 23.75)
# Index 277 worked for (90.25, 56.25)
# Index 278 worked for (90.75, 22.25)
# Index 279 worked for (92.25, 26.75)
# Index 280 worked for (93.25, 20.25)
# Index 281 worked for (96.75, 21.25)
# Index 282 worked for (97.75, 4.25)
# Index 283 worked for (97.75, 24.25)
# Index 284 worked for (99.75, 1.75)
# Index 285 worked for (99.75, 16.25)
# Index 286 worked for (100.25, 5.25)
# Index 287 worked for (101.25, 6.75)
# Index 288 worked for (102.25, 1.25)
# Index 289 worked for (102.75, 35.75)
# Index 290 worked for (103.75, 28.25)
# Index 291 worked for (103.75, 52.75)
# Index 292 worked for (104.25, 28.75)
# Index 293 worked for (104.25, 30.75)
# Index 294 worked for (104.75, 21.75)
# Index 295 worked for (104.75, 27.25)
# Index 296 worked for (105.25, 20.25)
# Index 297 worked for (105.25, 37.75)
# Index 298 worked for (106.25, 32.25)
# Index 299 worked for (107.75, 14.75)
# Index 300 worked for (107.75, 21.75)
# Index 301 worked for (107.75, 34.25)
# Index 302 worked for (108.25, -7.25)
# Index 303 worked for (108.25, 12.75)
# Index 304 worked for (108.25, 16.25)
# Index 305 worked for (108.75, 29.75)
# Index 306 worked for (109.75, 23.25)
# Index 307 worked for (109.75, 28.75)
# Index 308 worked for (110.75, 21.75)
# Index 309 worked for (111.75, 21.75)
# Index 310 worked for (111.75, 39.25)
# Index 311 worked for (112.25, 22.75)
# Index 312 worked for (112.25, 34.75)
# Index 313 worked for (112.75, 25.75)
# Index 314 worked for (113.25, 23.75)
# Index 315 worked for (113.25, 34.25)
# Index 316 worked for (113.75, -1.25)
# Index 317 worked for (113.75, 36.25)
# Index 318 worked for (114.25, 35.75)
# Index 319 worked for (114.25, 37.75)
# Index 320 worked for (114.75, 24.75)
# Index 321 worked for (114.75, 38.75)
# Index 322 worked for (114.75, 39.25)
# Index 323 worked for (115.25, 23.25)
# Index 324 worked for (115.25, 24.75)
# Index 325 worked for (115.75, 38.25)
# Index 326 worked for (117.25, 36.25)
# Index 327 worked for (118.25, 24.75)
# Index 328 worked for (118.75, 27.75)
# Index 329 worked for (118.75, 32.25)
# Index 330 worked for (119.25, -3.25)
# Index 331 worked for (119.25, 31.25)
# Index 332 worked for (119.25, 35.25)
# Index 333 worked for (119.75, 28.25)
# Index 334 worked for (119.75, 36.25)
# Index 335 worked for (120.75, 16.25)
# Index 336 worked for (120.75, 40.75)
# Index 337 worked for (121.25, 16.75)
# Index 338 worked for (121.25, 41.75)
# Index 339 worked for (121.75, 36.75)
# Index 340 worked for (122.25, 37.25)
# Index 341 worked for (122.25, 39.75)
# Index 342 worked for (122.25, 41.25)
# Index 343 worked for (122.75, 0.75)
# Index 344 worked for (122.75, 45.75)
# Index 345 worked for (124.25, 42.75)
# Index 346 worked for (124.75, 8.25)
# Index 347 worked for (124.75, 45.25)
# Index 348 worked for (125.75, 38.75)
# Index 349 worked for (125.75, 40.25)
# Index 350 worked for (125.75, 41.75)
# Index 351 worked for (125.75, 47.25)
# Index 352 worked for (126.75, 46.75)
# Index 353 worked for (127.25, 45.75)
# Index 354 worked for (129.25, 35.25)
# Index 355 worked for (129.25, 40.75)
# Index 356 worked for (137.25, 34.75)
# Index 357 worked for (137.75, -3.75)
# Index 358 worked for (138.75, 35.75)
# Index 359 worked for (140.75, 38.25)
# Index 360 worked for (140.75, 40.75)
# Index 361 worked for (141.25, 43.25)
# Index 362 worked for (142.75, -3.25)
# Index 363 worked for (144.75, -6.25)
