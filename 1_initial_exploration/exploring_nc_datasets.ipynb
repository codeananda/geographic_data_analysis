# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

path = Path('drive/My Drive/Work/Delivery/Joshua Banner/Work/')

# %%
# !pip install netcdf4

# %%
# Run this to crash the system and connect to runtime with more memory
# a = []
# while(1):
#     a.append('1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f13b8001d612> in <module>()
#       1 a = []
#       2 while(1):
# ----> 3     a.append('1')
#
# KeyboardInterrupt:

# %%
import pandas as pd
import xarray as xr

day = xr.open_dataset(path/'data/tas_day.nc')
day_max = xr.open_dataset(path/'data/tasmax_day.nc')
day_min = xr.open_dataset(path/'data/tasmin_day.nc')

# %%
day
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 360, lon: 720, time: 1826)
# Coordinates:
#   * lon        (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat        (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time       (time) datetime64[ns] 2006-01-01 2006-01-02 ... 2010-12-31
# Data variables:
#     tasAdjust  (time, lat, lon) float32 ...
# Attributes:
#     institution:      Potsdam Institute for Climate Impact Research, Research...
#     Conventions:      CF-1.6
#     title:            CMIP5 output of tas_day_GFDL-ESM2M_rcp85_r1i1p1, first-...
#     contact:          ISIMIP Coordination Team, Potsdam Institute for Climate...
#     project:          isimip2b
#     dataset_type:     Climate atmosphere simulated
#     bias_correction:  EWEMBI
#     world_region:     Global land
#     country:          ALL
#     model:            gfdl-esm2m
#     experiment:       rcp85
#     ensemble:         r1i1p1
#     time_frequency:   day
# ...

# %%
day_max
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 360, lon: 720, time: 1826)
# Coordinates:
#   * lon           (lon) float64 -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
#   * lat           (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time          (time) datetime64[ns] 2006-01-01 2006-01-02 ... 2010-12-31
# Data variables:
#     tasmaxAdjust  (time, lat, lon) float32 ...
# Attributes:
#     institution:      Potsdam Institute for Climate Impact Research, Research...
#     Conventions:      CF-1.6
#     title:            CMIP5 output of tasmax_day_GFDL-ESM2M_rcp85_r1i1p1, fir...
#     contact:          ISIMIP Coordination Team, Potsdam Institute for Climate...
#     project:          isimip2b
#     dataset_type:     Climate atmosphere simulated
#     bias_correction:  EWEMBI
#     world_region:     Global land
#     country:          ALL
#     model:            gfdl-esm2m
#     experiment:       rcp85
#     ensemble:         r1i1p1
#     time_frequency:   day
# ...

# %%
day_min
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 360, lon: 720, time: 1826)
# Coordinates:
#   * lon           (lon) float64 -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
#   * lat           (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time          (time) datetime64[ns] 2006-01-01 2006-01-02 ... 2010-12-31
# Data variables:
#     tasminAdjust  (time, lat, lon) float32 ...
# Attributes:
#     institution:      Potsdam Institute for Climate Impact Research, Research...
#     Conventions:      CF-1.6
#     title:            CMIP5 output of tasmin_day_GFDL-ESM2M_rcp85_r1i1p1, fir...
#     contact:          ISIMIP Coordination Team, Potsdam Institute for Climate...
#     project:          isimip2b
#     dataset_type:     Climate atmosphere simulated
#     bias_correction:  EWEMBI
#     world_region:     Global land
#     country:          ALL
#     model:            gfdl-esm2m
#     experiment:       rcp85
#     ensemble:         r1i1p1
#     time_frequency:   day
# ...

# %% [markdown]
# # Initial Thoughts
#
# For all the datasets the following is True:
# 1. `lon` - float64 and ends with .75, .25, .75, .25...
# 2. `lat` - float64 and ends wtih .75, .25, .75, .25...
#
# When I loaded them into my Jupyter Notebook, it said `lon` was .8, .2, .8, ... but now I've loaded them into Colab, they say .75, .25, .75, ... weird.
#
# But after looking at the DataFrame, it seems like both lat and lon end with .75, so not sure what is going on with the initial xarray read in but pandas thinks it is .75 and .25. This is good news.
#
#
# tas_day.nc has 473,299,200 rows.

# %%
# Took 29.2 seconds to execute in regular Jupyter Notebook!
# Much faster on Colab with GPU
day_df = day.to_dataframe()
day_max_df = day_max.to_dataframe()
day_min_df = day_min.to_dataframe()

# %%
day_df.shape
# Out:
# (473299200, 1)

# %%
no_nan = day_df.dropna()

# %%
no_nan_max = day_max_df.dropna()

# %%
no_nan_min = day_min_df.dropna()

# %%
no_nan.shape
# Out:
# (123108920, 1)

# %%
small = day_df.iloc[1000000:1040000, :]

# %%
small.tasAdjust.unique()
# Out:
# array([nan], dtype=float32)
